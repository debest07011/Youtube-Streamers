# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
import datetime as dt

# %%
df = pd.read_csv("youtube.csv")
df
# Out:
#      Rank              Username           Categories   Suscribers  \
# 0       1               tseries       Música y baile  249500000.0
# 1       2               MrBeast   Videojuegos, Humor  183500000.0
# 2       3             CoComelon            Educación  165500000.0
# 3       4              SETIndia                  NaN  162600000.0
# 4       5         KidsDianaShow  Animación, Juguetes  113500000.0
# ..    ...                   ...                  ...          ...
# 995   996          hamzymukbang                  NaN   11700000.0
# 996   997            Adaahqueen                  NaN   11700000.0
# 997   998  LittleAngelIndonesia       Música y baile   11700000.0
# 998   999          PenMultiplex                  NaN   11700000.0
# 999  1000         OneindiaHindi  Noticias y Política   11700000.0
#
#             Country       Visits      Likes  Comments  \
# 0             India      86200.0     2700.0      78.0
# 1    Estados Unidos  117400000.0  5300000.0   18500.0
# ...

# %%
df.shape
# Out:
# (1000, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rank        1000 non-null   int64
#  1   Username    1000 non-null   object
#  2   Categories  694 non-null    object
#  3   Suscribers  1000 non-null   float64
#  4   Country     1000 non-null   object
#  5   Visits      1000 non-null   float64
#  6   Likes       1000 non-null   float64
#  7   Comments    1000 non-null   float64
#  8   Links       1000 non-null   object
# dtypes: float64(4), int64(1), object(4)
# memory usage: 70.4+ KB

# %%
df.isnull().sum()
# Out:
# Rank            0
# Username        0
# Categories    306
# Suscribers      0
# Country         0
# Visits          0
# Likes           0
# Comments        0
# Links           0
# dtype: int64

# %%
df["Categories"] = df["Categories"].fillna("Unknown")
df["Categories"]
# Out:
# 0           Música y baile
# 1       Videojuegos, Humor
# 2                Educación
# 3                  Unknown
# 4      Animación, Juguetes
#               ...
# 995                Unknown
# 996                Unknown
# 997         Música y baile
# 998                Unknown
# 999    Noticias y Política
# Name: Categories, Length: 1000, dtype: object

# %%
df.describe()
# Out:
#               Rank    Suscribers        Visits         Likes       Comments
# count  1000.000000  1.000000e+03  1.000000e+03  1.000000e+03    1000.000000
# mean    500.500000  2.189440e+07  1.209446e+06  5.363259e+04    1288.768000
# std     288.819436  1.682775e+07  5.229942e+06  2.580457e+05    6778.188308
# min       1.000000  1.170000e+07  0.000000e+00  0.000000e+00       0.000000
# 25%     250.750000  1.380000e+07  3.197500e+04  4.717500e+02       2.000000
# 50%     500.500000  1.675000e+07  1.744500e+05  3.500000e+03      67.000000
# 75%     750.250000  2.370000e+07  8.654750e+05  2.865000e+04     472.000000
# max    1000.000000  2.495000e+08  1.174000e+08  5.300000e+06  154000.000000

# %%
df.describe(exclude="number")
# Out:
#           Username Categories         Country  \
# count         1000       1000            1000
# unique         994         46              29
# top     NickyJamTV    Unknown  Estados Unidos
# freq             2        306             293
#
#                                                     Links
# count                                                1000
# unique                                                994
# top     http://youtube.com/channel/UCpb_iJuhFe8V6rQdbN...
# freq                                                    2

# %%
df["Categories"].unique()
# Out:
# array(['Música y baile', 'Videojuegos, Humor', 'Educación', 'Unknown',
#        'Animación, Juguetes', 'Películas, Videojuegos', 'Juguetes',
#        'Videojuegos', 'Películas, Animación', 'Películas',
#        'Noticias y Política', 'Animación, Humor',
#        'Música y baile, Animación', 'Música y baile, Películas',
#        'Películas, Juguetes', 'Películas, Humor', 'Vlogs diarios',
#        'Videojuegos, Juguetes', 'Animación, Videojuegos', 'Animación',
#        'Música y baile, Humor', 'Diseño/arte, DIY y Life Hacks',
#        'Ciencia y tecnología', 'Fitness, Salud y autoayuda',
#        'Belleza, Moda', 'Humor', 'Comida y bebida', 'Deportes', 'Fitness',
#        'Viajes, Espectáculos', 'Comida y bebida, Salud y autoayuda',
#        'Diseño/arte', 'DIY y Life Hacks, Juguetes', 'Educación, Juguetes',
#        'Juguetes, Coches y vehículos', 'Música y baile, Juguetes',
#        'Animales y mascotas', 'ASMR', 'Moda', 'DIY y Life Hacks',
# ...

# %%
top_10_categories = Categories_count.nlargest(10).index
top_10_categories
# Out:
# Index(['Música y baile', 'Películas, Animación', 'Música y baile, Películas',
#        'Vlogs diarios', 'Noticias y Política', 'Películas, Humor',
#        'Animación, Videojuegos', 'Animación, Juguetes', 'Animación, Humor',
#        'Películas'],
#       dtype='object', name='Categories')

# %%
Top_10 = df[df['Categories'].isin(top_10_categories)]
Top_10.head()
# Out:
#     Rank         Username           Categories   Suscribers         Country  \
# 0      1          tseries       Música y baile  249500000.0           India
# 4      5    KidsDianaShow  Animación, Juguetes  113500000.0         Unknown
# 7      8      VladandNiki  Animación, Juguetes  101400000.0         Unknown
# 8      9  zeemusiccompany       Música y baile   99700000.0           India
# 10    11        BLACKPINK       Música y baile   91300000.0  Estados Unidos
#
#        Visits     Likes  Comments  \
# 0     86200.0    2700.0      78.0
# 4   3900000.0   12400.0       0.0
# 7   4100000.0   22100.0       0.0
# 8     74300.0    2600.0      32.0
# 10   863200.0  146900.0    3400.0
#
#                                                 Links
# 0   http://youtube.com/channel/UCq-Fj5jknLsUf-MWSy...
# 4   http://youtube.com/channel/UCk8GzjMOrta8yxDcKf...
# 7   http://youtube.com/channel/UCvlE5gTbOvjiolFlEm...
# 8   http://youtube.com/channel/UCFFbwnve3yF62-tVXk...
# ...

# %%
sns.countplot(df, x= "Categories")
# Out:
# <Axes: xlabel='Categories', ylabel='count'>

# %%
Correlation = ["Suscribers","Visits","Likes","Comments"]
corr = df[Correlation].corr()
corr
sns.heatmap(corr, annot=True, fmt=".1f")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(20,7))
sns.lineplot(df, x="Categories", y="Categories", color="red", ci=0)
plt.ylabel('Categories')
plt.xlabel('Category_counts')
plt.show()

# %%
top_10_df = top_10_categories.to_frame(name='Category_counts').reset_index()
top_10_df.columns = ['Categories', 'Category_counts']
top_10_df.columns
# Out:
# Index(['Categories', 'Category_counts'], dtype='object')

# %%
plt.figure(figsize=(20, 7))
sns.lineplot(data=top_10_df, x='Categories', y='Category_counts', color='red', ci=None)
plt.ylabel('Category Counts')
plt.xlabel('Categories')
plt.title('Top 10 Most Popular Categories')
plt.show()

# %%
top_5_subscribers = df.nlargest(5, 'Suscribers')[['Categories', 'Suscribers']]
print(top_5_subscribers)
# Out:
#             Categories   Suscribers
# 0       Música y baile  249500000.0
# 1   Videojuegos, Humor  183500000.0
# 2            Educación  165500000.0
# 3              Unknown  162600000.0
# 4  Animación, Juguetes  113500000.0

# %%
plt.figure(figsize=(7, 3))
sns.barplot(x='Suscribers', y='Categories', data=top_5_subscribers, palette='viridis')
plt.ylabel('Categories')
plt.title('Top 5 Categories by Subscribers')
plt.show()

# %%
top_5_Likes = df.nlargest(5, 'Likes')[['Categories', 'Likes']]
print(top_5_Likes)
# Out:
#              Categories      Likes
# 1    Videojuegos, Humor  5300000.0
# 136       Vlogs diarios  5000000.0
# 153    Animación, Humor  1700000.0
# 341               Humor  1400000.0
# 734             Unknown  1200000.0

# %%
plt.figure(figsize=(7, 3))
sns.barplot(x='Likes', y='Categories', data=top_5_Likes, palette='viridis')
plt.xlabel('Likes')
plt.ylabel('Categories')
plt.title('Top 5 Categories by Likes')
plt.show()

# %%
top_5_Visits = df.nlargest(5, 'Visits')[['Categories', 'Visits']]
print(top_5_Visits)
# Out:
#              Categories       Visits
# 1    Videojuegos, Humor  117400000.0
# 136       Vlogs diarios   83100000.0
# 153    Animación, Humor   52700000.0
# 288             Unknown   21500000.0
# 488     Comida y bebida   21500000.0

# %%
plt.figure(figsize=(7, 3))
sns.barplot(x='Visits', y='Categories', data=top_5_Visits, palette='viridis')
plt.xlabel('Visits')
plt.ylabel('Categories')
plt.title('Top 5 Categories by Visits')
plt.show()

# %%
top_5_Comments = df.nlargest(5, 'Comments')[['Categories', 'Comments']]
print(top_5_Comments)
# Out:
#                  Categories  Comments
# 436          Música y baile  154000.0
# 153        Animación, Humor   82800.0
# 958          Música y baile   73000.0
# 177  Animación, Videojuegos   52500.0
# 341                   Humor   38000.0

# %%
plt.figure(figsize=(7, 3))
sns.barplot(x='Comments', y='Categories', data=top_5_Comments, palette='viridis')
plt.xlabel('Comments')
plt.ylabel('Categories')
plt.title('Top 5 Categories by Comments')
plt.show()

# %%
total_subscribers = df["Suscribers"].sum()
print("Total_Subscribers = \t", total_subscribers)
# Out:
# Total_Subscribers = 	 21894400000.0

# %%
avg_subscribers = df["Suscribers"].mean()
print("Average_Subscribers = \t", avg_subscribers)
# Out:
# Average_Subscribers = 	 21894400.0

# %%
total_Visits = df["Visits"].sum()
print("Total_Visits = \t", total_Visits)
# Out:
# Total_Visits = 	 1209446315.5

# %%
avg_Visits = df["Visits"].mean()
print("Average_Visits = \t", avg_Visits)
# Out:
# Average_Visits = 	 1209446.3155

# %%
total_Likes = df["Likes"].sum()
print("Total_Likes = \t", total_Likes)
# Out:
# Total_Likes = 	 53632592.0

# %%
avg_Likes = df["Likes"].mean()
print("Average_Likes = \t", avg_Likes)
# Out:
# Average_Likes = 	 53632.592

# %%
total_Comments = df["Comments"].sum()
print("Total_Comments = \t", total_Comments)
# Out:
# Total_Comments = 	 1288768.0

# %%
avg_Comments = df["Comments"].mean()
print("Average_Comments = \t", avg_Comments)
# Out:
# Average_Comments = 	 1288.768

# %%
top_5_ = df.nlargest(5, 'Visits')[['Categories', 'Visits']]
print(top_5_Visits)
# Out:
#              Categories       Visits
# 1    Videojuegos, Humor  117400000.0
# 136       Vlogs diarios   83100000.0
# 153    Animación, Humor   52700000.0
# 288             Unknown   21500000.0
# 488     Comida y bebida   21500000.0

# %%
category_count = df["Categories"].value_counts()
category_count
# Out:
# Categories
# Unknown                               306
# Música y baile                        160
# Películas, Animación                   61
# Música y baile, Películas              41
# Vlogs diarios                          37
# Noticias y Política                    36
# Películas, Humor                       34
# Animación, Videojuegos                 34
# Animación, Juguetes                    29
# Animación, Humor                       27
# Películas                              24
# Educación                              24
# Animación                              22
# Videojuegos                            19
# Videojuegos, Humor                     17
# Música y baile, Animación              16
# Ciencia y tecnología                   14
# Comida y bebida                        12
# Humor                                  10
# Juguetes                               10
# Películas, Juguetes                     9
# Películas, Videojuegos                  8
# ...

# %%
cate = Categories_count.nlargest(10)
cate
# Out:
# Categories
# Música y baile               160
# Películas, Animación          61
# Música y baile, Películas     41
# Vlogs diarios                 37
# Noticias y Política           36
# Películas, Humor              34
# Animación, Videojuegos        34
# Animación, Juguetes           29
# Animación, Humor              27
# Películas                     24
# Name: count, dtype: int64

# %%
above_average_streamers = df[
    (df['Suscribers'] > avg_subscribers) &
    (df['Visits'] > avg_Visits) &
    (df['Likes'] > avg_Likes) &
    (df['Comments'] > avg_Comments)]
above_average_streamers
# Out:
#      Rank               Username                     Categories   Suscribers  \
# 1       2                MrBeast             Videojuegos, Humor  183500000.0
# 5       6              PewDiePie         Películas, Videojuegos  111500000.0
# 26     27            dudeperfect                    Videojuegos   59700000.0
# 34     35            TaylorSwift                 Música y baile   54100000.0
# 39     40            JuegaGerman           Películas, Animación   48600000.0
# 43     44               A4a4a4a4               Animación, Humor   47300000.0
# 58     59              Mikecrack           Películas, Animación   43400000.0
# 62     63         KimberlyLoaiza                 Música y baile   42100000.0
# 64     65        luisitocomunica                        Unknown   41100000.0
# 70     71            JessNoLimit           Películas, Animación   39600000.0
# 96     97         TotalGaming093         Películas, Videojuegos   36300000.0
# ...

# %%
df.head()
# Out:
#    Rank       Username           Categories   Suscribers         Country  \
# 0     1        tseries       Música y baile  249500000.0           India
# 1     2        MrBeast   Videojuegos, Humor  183500000.0  Estados Unidos
# 2     3      CoComelon            Educación  165500000.0         Unknown
# 3     4       SETIndia                  NaN  162600000.0           India
# 4     5  KidsDianaShow  Animación, Juguetes  113500000.0         Unknown
#
#         Visits      Likes  Comments  \
# 0      86200.0     2700.0      78.0
# 1  117400000.0  5300000.0   18500.0
# 2    7000000.0    24700.0       0.0
# 3      15600.0      166.0       9.0
# 4    3900000.0    12400.0       0.0
#
#                                                Links
# 0  http://youtube.com/channel/UCq-Fj5jknLsUf-MWSy...
# 1  http://youtube.com/channel/UCX6OQ3DkcsbYNE6H8u...
# 2  http://youtube.com/channel/UCbCmjCuTUZos6Inko4...
# 3  http://youtube.com/channel/UCpEhnqL0y41EpW2TvW...
# ...

# %%
top_5_Username = df.nlargest(5, 'Suscribers')[['Username', 'Suscribers']]
print(top_5_Username)
# Out:
#         Username   Suscribers
# 0        tseries  249500000.0
# 1        MrBeast  183500000.0
# 2      CoComelon  165500000.0
# 3       SETIndia  162600000.0
# 4  KidsDianaShow  113500000.0

# %%
top_5_Username = df.nlargest(5, 'Visits')[['Username', 'Visits']]
print(top_5_Username)
# Out:
#                   Username       Visits
# 1                  MrBeast  117400000.0
# 136               MrBeast2   83100000.0
# 153              DaFuqBoom   52700000.0
# 288  VillageCookingChannel   21500000.0
# 488      BeastPhilanthropy   21500000.0

# %%
top_5_Username = df.nlargest(5, 'Comments')[['Username', 'Comments']]
print(top_5_Username)
# Out:
#                Username  Comments
# 436  BispoBrunoLeonardo  154000.0
# 153           DaFuqBoom   82800.0
# 958             dojacat   73000.0
# 177              DanTDM   52500.0
# 341     triggeredinsaan   38000.0

# %%
top_5_Username = df.nlargest(5, 'Likes')[['Username', 'Likes']]
print(top_5_Username)
# Out:
#             Username      Likes
# 1            MrBeast  5300000.0
# 136         MrBeast2  5000000.0
# 153        DaFuqBoom  1700000.0
# 341  triggeredinsaan  1400000.0
# 734          Mythpat  1200000.0
